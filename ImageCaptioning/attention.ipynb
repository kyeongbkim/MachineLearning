# %%
import imp
import os
import tensorflow as tf
import pandas as pd
import numpy as np
from keras_preprocessing.sequence import pad_sequences

import image_captioning
import attention

# %%
icap = attention.ImageCaptioningWithAttention(
#    dataset_name='Flickr8k'
#    dataset_name='Flickr30k'
    dataset_name='Flickr30k_8000_0.8'
)
# Out:
# Loading prebuilt vocabulary ./workspace/Flickr30k_8000_0.8-vocab.pkl ... completed
# Loading caption sequences ./workspace/Flickr30k_8000_0.8-caption_sequences.pkl ... completed
# Loading prebuilt embedding matrix ./workspace/Flickr30k_8000_0.8-embedding_matrix_fasttext.pkl ... completed
# Building image features ./workspace/Flickr30k-vgg16-no_include_top ... 8000/8000 processed. 100% completed
# Building training model ... completed

# %%
icap.clear_checkpoints()

checkpoints = [ 10, 20, 30, 40, 50]
for epoch in checkpoints:
    icap.train(epoch)
    icap.save_weights(epoch)
# Out:
# Epoch 1/10
# 500/500 [==============================] - 128s 144ms/step - loss: 4.3562
# Epoch 2/10
# 500/500 [==============================] - 72s 143ms/step - loss: 2.9682
# Epoch 3/10
# 500/500 [==============================] - 72s 143ms/step - loss: 2.6624
# Epoch 4/10
# 500/500 [==============================] - 72s 144ms/step - loss: 2.4564
# Epoch 5/10
# 500/500 [==============================] - 72s 144ms/step - loss: 2.2950
# Epoch 6/10
# 500/500 [==============================] - 72s 144ms/step - loss: 2.2119
# Epoch 7/10
# 500/500 [==============================] - 72s 144ms/step - loss: 2.0585
# Epoch 8/10
# 500/500 [==============================] - 72s 143ms/step - loss: 1.9413
# Epoch 9/10
# 500/500 [==============================] - 71s 143ms/step - loss: 1.8508
# Epoch 10/10
# 500/500 [==============================] - 71s 143ms/step - loss: 1.7714
# Saving weights ./workspace/Flickr30k_8000_0.8-attention/ckpt-10
# Epoch 11/20
# ...

# %%
icap.sample_test(icap.caption_data.test_images[0], show_image=True)
# Out:
# Predicted:  a black and white dog running in a grassy field
# Reference:
#      A recently adopted mixed breed medium sized dog bounds happily around the yard .
#      A cream colored dog runs through green grass .
#      A yellow dog runs through the grass .
#      A yellow dog running across a lawn .
#      A dog runs through the grass .

# %%
icap.sample_test(icap.caption_data.test_images[-1], show_image=True)
# Out:
# Predicted:  a man in blue jeans kneels down the sidewalk .
# Reference:
#      A tattooed man sitting on a sidewalk has pulled the neck of his shirt up over his face .
#      A man sits on the sidewalk , head in hands and shirt over his eyes .
#      Dejected man sits crossed-legged with head in hands .
#      A man sitting on sidewalk with shirt over his head .
#      Depressed man who does not know what to do .
